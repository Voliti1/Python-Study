# %% [markdown]
# # API란 무엇인가?
#
# **API(Application Programming Interface)** 는 서로 다른 소프트웨어 시스템 간에 정보를 주고받거나 기능을 사용할 수 있도록 도와주는 서비스임.
#
# 쉽게 말하면, **"요청하면 필요한 데이터를 보내주는 자동화된 시스템"**
#
# ---
#
# # 이번에 사용한 3개의 API 소개 및 활용 방법
# | API | 주요 기능 | 활용 가능성 |
# |:---|:---------|:-------------|
# | The Cat API | 랜덤 고양이 사진 | 갤러리, 알림, 앱 삽입 |
# | Open-Meteo API | 현재/예보 날씨 데이터 | 날씨 앱, 일정 추천 |
# | ZenQuotes API | 랜덤 명언 제공 | 동기부여 앱, 다이어리 |
#
# ---
#
# ## 1. 고양이 사진 API (The Cat API)
#
# ### 소개
# - 전 세계 고양이 사진을 무료로 제공하는 공개 API입니다.
# - 랜덤 고양이 사진이나, 특정 품종의 고양이 사진도 가져올 수 있습니다.
#
# ### 공식 문서
# - https://docs.thecatapi.com/
#
# ### 주요 활용 방법
# | 항목 | 내용 |
# |:-----|:----|
# | URL | `https://api.thecatapi.com/v1/images/search` |
# | 요청 방식 | GET |
# | 인증키 필요 여부 | 기본 사용은 필요 없음 |
# | 반환 데이터 | 고양이 이미지 URL 리스트 (JSON)
#
# ### 대표 예제 코드
# ```python
# import requests
# from IPython.display import Image, display
#
# url = "https://api.thecatapi.com/v1/images/search"
# response = requests.get(url)
# data = response.json()
# cat_url = data[0]['url']
#
# print("오늘의 고양이 사진:")
# display(Image(url=cat_url))
# ```
#
# ### 반환되는 JSON 구조 예시
# ```json
# [
#   {
#     "id": "MTY3ODIyMQ",
#     "url": "https://cdn2.thecatapi.com/images/MTY3ODIyMQ.jpg",
#     "width": 1080,
#     "height": 1350
#   }
# ]
# ```

# %%
import requests
from IPython.display import Image, display

url = "https://api.thecatapi.com/v1/images/search"
response = requests.get(url)
data = response.json()
cat_url = data[0]['url']

print("오늘의 고양이 사진:")
display(Image(url=cat_url))
# Out:
# 오늘의 고양이 사진:
# <img src="https://cdn2.thecatapi.com/images/2np.jpg"/>

# %% [markdown]
# ## 2. 날씨 정보 API (Open-Meteo API)
#
# ### 소개
# - 위치(위도, 경도)를 기준으로 현재 날씨, 예보, 기온, 풍속 등 다양한 날씨 정보를 제공합니다.
# - 무료이며, 인증키 없이 바로 사용할 수 있습니다.
#
# ### 공식 문서
# - https://open-meteo.com/en/docs
#
# ### 주요 활용 방법
# | 항목 | 내용 |
# |:-----|:----|
# | URL | `https://api.open-meteo.com/v1/forecast` |
# | 요청 방식 | GET |
# | 인증키 필요 여부 | 필요 없음 |
# | 반환 데이터 | 날씨 정보 (JSON)
#
# ### 대표 예제 코드
# ```python
# import requests
# from datetime import datetime
#
# latitude = 37.5665
# longitude = 126.9780
# today = datetime.utcnow().date()
#
# url = (
#     f"https://api.open-meteo.com/v1/forecast?"
#     f"latitude={latitude}&longitude={longitude}"
#     f"&daily=temperature_2m_max,temperature_2m_min&timezone=Asia%2FSeoul"
# )
# response = requests.get(url)
# data = response.json()
#
# dates = data['daily']['time']
# max_temps = data['daily']['temperature_2m_max']
# min_temps = data['daily']['temperature_2m_min']
#
# for i, date in enumerate(dates):
#     if date == str(today):
#         print(f"오늘({today}) 서울 날씨")
#         print(f"- 최고 기온: {max_temps[i]}°C")
#         print(f"- 최저 기온: {min_temps[i]}°C")
# ```
#
# ### 반환되는 JSON 구조 예시
# ```json
# {
#   "daily": {
#     "time": ["2025-04-07", "2025-04-08"],
#     "temperature_2m_max": [18.5, 20.1],
#     "temperature_2m_min": [9.2, 10.5]
#   }
# }
# ```

# %%
import requests
from datetime import datetime

latitude = 37.008229
longitude = 127.176435
today = datetime.utcnow().date()
#today= '2025-04-14'
url = (
    f"https://api.open-meteo.com/v1/forecast?"
    f"latitude={latitude}&longitude={longitude}"
    f"&daily=temperature_2m_max,temperature_2m_min&timezone=Asia%2FSeoul"
)
response = requests.get(url)
data = response.json()
dates = data['daily']['time']
max_temps = data['daily']['temperature_2m_max']
min_temps = data['daily']['temperature_2m_min']

for date in dates:
    if date == str(today):
        i = dates.index(date)
        print(f"오늘({today}) 안성 날씨")
        print(f"- 최고 기온: {max_temps[i]}°C")
        print(f"- 최저 기온: {min_temps[i]}°C")
        break
# Out:
# 오늘(2026-03-26) 안성 날씨
# - 최고 기온: 15.7°C
# - 최저 기온: 2.8°C

# %% [markdown]
# ## 3. 명언 제공 API (ZenQuotes API)
#
# ### 소개
# - 전 세계 다양한 명언을 랜덤하게 제공합니다.
# - 별도의 회원가입 없이 사용할 수 있습니다.
#
# ### 공식 문서
# - https://zenquotes.io/api
#
# ### 주요 활용 방법
# | 항목 | 내용 |
# |:-----|:----|
# | URL | `https://zenquotes.io/api/random` |
# | 요청 방식 | GET |
# | 인증키 필요 여부 | 필요 없음 (하루 50회 제한) |
# | 반환 데이터 | 명언 리스트 (JSON)
#
# ### 대표 예제 코드
# ```python
# import requests
#
# url = "https://zenquotes.io/api/random"
# response = requests.get(url)
# data = response.json()
#
# quote = data[0]['q']
# author = data[0]['a']
#
# print("오늘의 명언:")
# print(f'"{quote}" — {author}')
# ```
#
# ### 반환되는 JSON 구조 예시
# ```json
# [
#   {
#     "q": "Be yourself; everyone else is already taken.",
#     "a": "Oscar Wilde"
#   }
# ]
# ```

# %%
import requests

url = "https://zenquotes.io/api/random"
response = requests.get(url)
data = response.json()
print(data)
import json
print(json.dumps(data, indent=3))

quote = data[0]['q']
author = data[0]['a']

print("오늘의 명언:")
print(f'"{quote}" — {author}')
# Out:
# [{'q': 'Perfection is not attainable, but if we chase perfection we can catch excellence.', 'a': 'Vince Lombardi', 'h': '<blockquote>&ldquo;Perfection is not attainable, but if we chase perfection we can catch excellence.&rdquo; &mdash; <footer>Vince Lombardi</footer></blockquote>'}]
# [
#    {
#       "q": "Perfection is not attainable, but if we chase perfection we can catch excellence.",
#       "a": "Vince Lombardi",
#       "h": "<blockquote>&ldquo;Perfection is not attainable, but if we chase perfection we can catch excellence.&rdquo; &mdash; <footer>Vince Lombardi</footer></blockquote>"
#    }
# ]
# 오늘의 명언:
# "Perfection is not attainable, but if we chase perfection we can catch excellence." — Vince Lombardi

# %% [markdown]
# ###아침 루틴 만들기(Routine 클래스의 routine 메소드)
# 1. 랜덤 고양이 사진 보여주기(메소드)
# 2. 오늘 서울 날씨 알려주기(메소드)
# 3. 오늘의 명언 출력하기(메소드)
# 4. 추가 기능 제공(자율)

# %%
import requests
from datetime import datetime
from IPython.display import Image, display

# 1. 고양이 사진
def cat():
    url = "https://api.thecatapi.com/v1/images/search"
    response = requests.get(url)
    data = response.json()
    cat_url = data[0]['url']
    print("\n🐈 오늘의 고양이 사진:")
    display(Image(url=cat_url, width=300))

# 2. 안성 날씨
def weather():
    latitude = 37.008229
    longitude = 127.176435
    today = datetime.now().date()
    url = (
        f"https://api.open-meteo.com/v1/forecast?"
        f"latitude={latitude}&longitude={longitude}"
        f"&daily=temperature_2m_max,temperature_2m_min&timezone=Asia%2FSeoul"
    )
    response = requests.get(url)
    data = response.json()
    dates = data['daily']['time']
    max_temps = data['daily']['temperature_2m_max']
    min_temps = data['daily']['temperature_2m_min']

    for i, date in enumerate(dates):
        if date == str(today):
            print(f"☀️ 오늘({today}) 안성 날씨")
            print(f"- 최고 기온: {max_temps[i]}°C")
            print(f"- 최저 기온: {min_temps[i]}°C")
            break

# 3. 명언
def quote():
    url = "https://zenquotes.io/api/random"
    response = requests.get(url)
    data = response.json()
    q = data[0]['q']
    a = data[0]['a']
    print(f"\n📖 오늘의 명언:\n\"{q}\" — {a}")

# 4. 비트코인
def bitcoin(my_api_key):
    headers = {
        "accept": "application/json",
        "x-cg-demo-api-key": my_api_key
    }

    url = "https://api.coingecko.com/api/v3/simple/price?ids=bitcoin&vs_currencies=krw&include_24hr_change=true"
    
    try:
        response = requests.get(url, headers=headers)
        data = response.json()
        
        price = data['bitcoin']['krw']
        change = data['bitcoin']['krw_24h_change']
        
        print("\n🪙 오늘의 비트코인 시세:")
        print(f"- 현재가: {price:,} 원")
        print(f"- 24시간 전 대비: {change:.2f}%")
    except Exception as e:
        print(f"\n🪙 코인 정보를 가져오지 못했습니다. 키를 확인해주세요! ({e})")

def exchange(api_key):
    # 기준 통화를 USD(미국 달러)로 설정
    url = f"https://v6.exchangerate-api.com/v6/{api_key}/latest/USD"
    
    try:
        response = requests.get(url)
        data = response.json()
        
        if data['result'] == 'success':
            # USD 대비 KRW(한국 원) 환율
            krw_rate = data['conversion_rates']['KRW']
            # JPY(일본 엔) 환율
            jpy_rate = data['conversion_rates']['JPY']
            
            print("\n💵 오늘의 주요 환율 (1달러 기준):")
            print(f"- 원화(KRW): {krw_rate:,.2f} 원")
            print(f"- 엔화(JPY): {jpy_rate:,.2f} 엔")
        else:
            print("\n💵 환율 정보를 가져오는 데 실패했습니다.")
    except Exception as e:
        print(f"\n💵 환율 API 오류: {e}")

# --- 실행 부분 ---
def routine():
    # 본인의 API 키를 여기에 따옴표와 함께 적어주세요.
    COINGECKO_KEY = "" 
    EXCHANGE_KEY = ""

    weather()
    exchange(EXCHANGE_KEY)
    bitcoin(COINGECKO_KEY)
    quote()
    cat()

routine()
# Out:
# ☀️ 오늘(2026-03-26) 안성 날씨
# - 최고 기온: 15.7°C
# - 최저 기온: 2.8°C
#
# 💵 오늘의 주요 환율 (1달러 기준):
# - 원화(KRW): 1,501.66 원
# - 엔화(JPY): 159.19 엔
#
# 🪙 오늘의 비트코인 시세:
# - 현재가: 106,898,680 원
# - 24시간 전 대비: 1.32%
#
# 📖 오늘의 명언:
# "Decide what your truth is. Then live it." — Kamal Ravikant
#
# 🐈 오늘의 고양이 사진:
# <img src="https://cdn2.thecatapi.com/images/cga.jpg" width="300"/>

# %% [markdown]
# https://opendict.korean.go.kr/api/search?certkey_no=8917&key=4FFAF72BE3F45EA48551E923062FCA5E&target_type=search&req_type=xml&part=word&q=%EB%AC%B4&sort=dict&start=1&num=10&pos=1&letter_s=2

# %%
import requests
import json
import random

apikey = '4FFAF72BE3F45EA48551E923062FCA5E'

while True:
    player = input('사용자 : ')
    
    #종료조건
    if player == '그만':
        break
        
    query = player[-1]
    url = 'https://opendict.korean.go.kr/api/search?certkey_no=8917&key='+apikey+'&target_type=search&req_type=json&part=word&sort=popular&start=1&num=100&pos=1&q='+query
    response = requests.get(url)

    words = json.loads(response.text)

    list_a = []

    for i in range(10):
        if words['channel']['item'][i]['sense']['word'][0]==query:
            list_a.append(words['channel']['item'][i]['sense']['word'].replace('-', "").replace("^", " "))

    # 리스트가 비어있을 경우
    if list_a:
        print("컴퓨터 : "+ random.choice(list_a))
    else:
        print("컴퓨터 : 대답할 단어가 없습니다.")
        
    print(url)
# Out:
# 컴퓨터 : 무달
# https://opendict.korean.go.kr/api/search?certkey_no=8917&key=4FFAF72BE3F45EA48551E923062FCA5E&target_type=search&req_type=json&part=word&sort=popular&start=1&num=100&pos=1&q=무
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 14
#      11 if player == '그만':
#      12     break
# ---> 14 query = player[-1]
#      15 url = 'https://opendict.korean.go.kr/api/search?certkey_no=8917&key='+apikey+'&target_type=search&req_type=json&part=word&sort=popular&start=1&num=100&pos=1&q='+query
#      16 response = requests.get(url)
#
# IndexError: string index out of range

# %%
import requests
import json
import random
import os
# ★ 주피터 노트북 전용 출력 제어 라이브러리 추가
from IPython.display import clear_output 

apikey = '4FFAF72BE3F45EA48551E923062FCA5E'
list_used = []  # 사용한 단어 저장 리스트
com_word = ""   # 컴퓨터가 마지막으로 말한 단어 저장 변수
msg_error = ""  # 에러 메시지 저장

def clear_screen():
    """주피터 노트북의 셀 출력부를 깨끗하게 지움"""
    # wait=True는 다음 출력이 올 때까지 기다렸다가 지워주어 화면 깜빡임을 줄여줍니다.
    clear_output(wait=True)

def get_dueum(word):
    """단어의 마지막 글자에 대한 두음법칙 적용 글자 반환"""
    if not word: return ""
    char = word[-1]
    code = ord(char) - 44032
    if code < 0 or code > 11171: return char
    cho = (code // 28) // 21
    jung = (code // 28) % 21
    jong = code % 28
    if cho == 5:
        if jung in [2, 4, 7, 12, 17, 20]:
            return chr(44032 + (11 * 21 + jung) * 28 + jong)
        else:
            return chr(44032 + (2 * 21 + jung) * 28 + jong)
    elif cho == 2:
        if jung in [4, 12, 17, 20]:
            return chr(44032 + (11 * 21 + jung) * 28 + jong)
    return char

def display_game():
    """현재 게임 상태를 주피터 셀에 상시 고정 출력"""
    clear_screen()
    print("="*45)
    print("        [ 🤖 AI 끝말잇기 - Jupyter Mode ]")
    print("="*45)
    
    if list_used:
        print("\n📜 현재 사용된 단어 리스트")
        for i in range(0, len(list_used), 10):
            line = list_used[i:i+10]
            print(f"[{i+1:02d}~{i+len(line):02d}]: {', '.join(line)}")
        print("-" * 45)
    
    if com_word:
        dueum = get_dueum(com_word)
        target = f"'{com_word[-1]}'" if com_word[-1] == dueum else f"'{com_word[-1]}' 또는 '{dueum}'"
        print(f"\n💬 컴퓨터: {com_word}")
        print(f"👉 {target}(으)로 시작하는 2글자 이상의 단어를 입력하세요.")
    else:
        print("\n🚀 첫 단어를 입력하여 게임을 시작하세요! (2글자 이상)")

# 메인 게임 루프
while True:
    while True:
        display_game()
        if msg_error:
            print(f"\n⚠️  경고: {msg_error}")
            msg_error = "" # 출력 후 초기화
            
        player = input('\n입력창 ⌨️ : ').strip()
        
        if player == '그만':
            break
            
        # [규칙 1] 두 글자 이상 제한
        if len(player) < 2:
            msg_error = "두 글자 이상의 단어만 입력할 수 있습니다."
            continue

        # [규칙 2] 끝말잇기 성립 여부 (두음법칙 포함)
        if com_word != "":
            dueum_target = get_dueum(com_word)
            if player[0] != com_word[-1] and player[0] != dueum_target:
                msg_error = f"'{com_word[-1]}'(으)로 시작해야 합니다."
                continue 
        
        # [규칙 3] 중복 확인
        if player in list_used:
            msg_error = f"'{player}'은(는) 이미 사용한 단어입니다."
            continue

        # [규칙 4] 사전 확인
        check_url = f'https://opendict.korean.go.kr/api/search?certkey_no=8917&key={apikey}&target_type=search&req_type=json&part=word&q={player}'
        is_valid = False
        try:
            check_res = requests.get(check_url)
            check_data = json.loads(check_res.text)
            if 'item' in check_data['channel']:
                for item in check_data['channel']['item']:
                    target = item['word'].replace('-', '').replace('^', '')
                    if target == player:
                        is_valid = True
                        break
            if not is_valid:
                msg_error = f"'{player}'은(는) 사전에 없는 단어입니다."
                continue
        except:
            msg_error = "네트워크 연결을 확인해주세요."
            continue
        break
    
    if player == '그만':
        print("\n👋 게임을 종료합니다. 수고하셨습니다!")
        break
        
    list_used.append(player)
    
    # 컴퓨터 답변 로직
    search_chars = list(set([player[-1], get_dueum(player)]))
    list_a = []
    for query in search_chars:
        url = f'https://opendict.korean.go.kr/api/search?certkey_no=8917&key={apikey}&target_type=search&req_type=json&part=word&sort=popular&start=1&num=50&pos=1&type3=general&q={query}'
        try:
            response = requests.get(url)
            words = json.loads(response.text)
            if 'item' in words['channel']:
                for item in words['channel']['item']:
                    target_word = item.get('sense', item).get('word').replace("-", "").replace("^", "")
                    if len(target_word) >= 2 and target_word[0] == query:
                        list_a.append(target_word)
        except:
            continue

    candidates = list(set(list_a) - set(list_used))
    if candidates:
        com_word = random.choice(candidates)
        list_used.append(com_word)
    else:
        display_game()
        print("\n🎊 축하합니다! 컴퓨터가 패배했습니다!")
        input("\n(엔터를 누르면 새 게임이 시작됩니다)")
        list_used = []
        com_word = ""
# Out:
# ...
#         [ 🤖 AI 끝말잇기 - Jupyter Mode ]
# ...
#
# 🚀 첫 단어를 입력하여 게임을 시작하세요! (2글자 이상)
#
# ⚠️  경고: 두 글자 이상의 단어만 입력할 수 있습니다.
#
# 👋 게임을 종료합니다. 수고하셨습니다!

# %%
import requests
import json
import random
from IPython.display import clear_output 

apikey = '4FFAF72BE3F45EA48551E923062FCA5E'
list_used = []
com_word = ""

def get_dueum(word):
    """두음법칙 변환 함수 (기존과 동일)"""
    if not word: return ""
    char = word[-1]
    code = ord(char) - 44032
    if code < 0 or code > 11171: return char
    cho = (code // 28) // 21
    jung = (code // 28) % 21
    jong = code % 28
    if cho == 5:
        if jung in [2, 4, 7, 12, 17, 20]:
            return chr(44032 + (11 * 21 + jung) * 28 + jong)
        else:
            return chr(44032 + (2 * 21 + jung) * 28 + jong)
    elif cho == 2:
        if jung in [4, 12, 17, 20]:
            return chr(44032 + (11 * 21 + jung) * 28 + jong)
    return char

def display_game(msg_error=""):
    """화면 출력 함수 (기존 로직 유지)"""
    clear_output(wait=True)
    print("="*45)
    print("        [ 🤖 AI 끝말잇기 - 재귀 모드 ]")
    print("="*45)
    
    if list_used:
        print("\n📜 현재 사용된 단어 리스트")
        for i in range(0, len(list_used), 10):
            line = list_used[i:i+10]
            print(f"[{i+1:02d}~{i+len(line):02d}]: {', '.join(line)}")
        print("-" * 45)
    
    if com_word:
        dueum = get_dueum(com_word)
        target = f"'{com_word[-1]}'" if com_word[-1] == dueum else f"'{com_word[-1]}' 또는 '{dueum}'"
        print(f"\n💬 컴퓨터: {com_word}")
        print(f"👉 {target}(으)로 시작하는 2글자 이상의 단어를 입력하세요.")
    else:
        print("\n🚀 첫 단어를 입력하여 게임을 시작하세요! (2글자 이상)")
        
    if msg_error:
        print(f"\n⚠️  경고: {msg_error}")

def play_game():
    """메인 로직 함수: while 대신 재귀 호출 사용"""
    global com_word, list_used
    
    display_game()
    player = input('\n입력창 ⌨️ : ').strip()
    
    # 종료 조건
    if player == '그만':
        print("\n👋 게임을 종료합니다. 수고하셨습니다!")
        return

    # 1. 사용자 단어 검증 로직
    error = ""
    if len(player) < 2:
        error = "두 글자 이상의 단어만 입력할 수 있습니다."
    elif com_word and player[0] != com_word[-1] and player[0] != get_dueum(com_word):
        error = f"'{com_word[-1]}'(으)로 시작해야 합니다."
    elif player in list_used:
        error = f"'{player}'은(는) 이미 사용한 단어입니다."
    
    if error:
        display_game(error)
        # 잘못 입력했으므로 다시 내 차례 호출 (while문의 continue 역할)
        return play_game()

    # 2. 사전 확인 로직
    check_url = f'https://opendict.korean.go.kr/api/search?certkey_no=8917&key={apikey}&target_type=search&req_type=json&part=word&q={player}'
    try:
        res = requests.get(check_url).json()
        is_valid = any(item['word'].replace('-', '').replace('^', '') == player 
                       for item in res.get('channel', {}).get('item', []))
        if not is_valid:
            display_game(f"'{player}'은(는) 사전에 없는 단어입니다.")
            return play_game()
    except:
        display_game("네트워크 연결 오류!")
        return play_game()

    # 모든 검증 통과
    list_used.append(player)

    # 3. 컴퓨터 답변 찾기
    search_chars = list(set([player[-1], get_dueum(player)]))
    candidates = []
    
    for query in search_chars:
        url = f'https://opendict.korean.go.kr/api/search?certkey_no=8917&key={apikey}&target_type=search&req_type=json&part=word&sort=popular&start=1&num=50&pos=1&type3=general&q={query}'
        try:
            words = requests.get(url).json()
            items = words.get('channel', {}).get('item', [])
            for item in items:
                target = item.get('sense', item).get('word').replace("-", "").replace("^", "")
                if len(target) >= 2 and target[0] == query and target not in list_used:
                    candidates.append(target)
        except: continue

    if candidates:
        com_word = random.choice(list(set(candidates)))
        list_used.append(com_word)
        # 컴퓨터가 대답했으므로 다음 턴 호출 (while문의 반복 역할)
        play_game()
    else:
        display_game()
        print("\n🎊 축하합니다! 컴퓨터가 패배했습니다!")
        input("\n(엔터를 누르면 새 게임이 시작됩니다)")
        list_used = []
        com_word = ""
        play_game()

# 게임 시작
play_game()
