# %%
num = input("수를 입력해주세요")
print(int(num) ** 2)
# Out:
# 81

# %%
text = '20241014sunny'

year = text[0:4]
month = text[4:6]
day = text[6:8]
weather = text[8:]

print(year); print(month); print(day); print(weather);
# Out:
# 2024
# 10
# 14
# sunny

# %%
kor = 80; eng = 75; math = 55
avg = (kor + eng + math)/ 3
print("홍길동 씨의 평균점수 : %d점" % int(avg))
# Out:
# 홍길동 씨의 평균점수 : 70점

# %%
list = [1, 3, 5, 4, 2]
list.sort(); list.reverse()
print(list)
# Out:
# [5, 4, 3, 2, 1]

# %%
name = "홍길동"
num = "881120-1068234"
year = num[:2]
month = num[2:4]
day = num[4:6]
backnum = num[7:]
sex = num[7]

print("성함 : %s," %name," 생년 : %s," %year, "월 : %s," %month, "일 : %s," %day, "뒷자리: %s" %backnum)
print(sex)
# Out:
# 성함 : 홍길동,  생년 : 88, 월 : 11, 일 : 20, 뒷자리: 1068234
# 1

# %%
a = "a:b:c:d"
b = a.replace(":", "#")

print(b)
# Out:
# a#b#c#d

# %%
#Q10

a = {'A':90,'B':80, 'C':70}
a.pop('B')
# Out:
# 80

# %%
#Q11

a = [1, 1, 1, 2, 2, 3, 3, 3, 4, 4, 5]

del a[9]; del a[7]; del a[6]; del a[4]; del a[2]; del a[1]
print(a)
# Out:
# [1, 2, 3, 4, 5]
