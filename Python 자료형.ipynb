# %% [markdown]
# # Python
#
#
# ## Variable
#
# Memory area for saving some value
#
# ## Data Type
#
# **Int**
# - Int is a datatype for Integer
# - ex) 0, -1, 1
#
# **Float**
# - Float is a datatype for real number
# - Word 'Float' is from Floating Point
# - ex) 0.0, -1.2, 123.456

# %% [markdown]
# # Operators
# <br>
# a = 3, b = 2 <br><br>
# +<br>
# a + b = 5 <br>
# -<br>
# a - b = 1<br>
# *<br>
# a * b = 6<br>
# /<br>
# a / b = 1.5<br>
# //<br>
# a // b = 1<br>
# %<br>
# a % b = 1<br>
# **<br>
# a ** b = 9<br>
